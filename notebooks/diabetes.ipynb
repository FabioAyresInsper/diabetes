# %%
import pathlib

filename = pathlib.Path.cwd().parent / 'data' / 'visceral_fat.csv'
filename
# Out:
# PosixPath('/home/fjayres/Dropbox/Insper/Disciplinas/MachineLearning/2023-1/sandbox/diabetes/data/visceral_fat.csv')

# %%
import pandas as pd

data = pd.read_csv(filename)

# %%
data
# Out:
#      number  age (years)  ethnicity  diabetes mellitus  \
# 0         1           20        NaN                  0
# 1         2           28        0.0                  0
# 2         5           21        1.0                  0
# 3         9           25        0.0                  0
# 4        13           33        1.0                  0
# ..      ...          ...        ...                ...
# 128     278           21        0.0                  0
# 129     280           22        0.0                  0
# 130     283           19        1.0                  0
# 131     285           23        1.0                  0
# 132     287           36        0.0                  0
#
#      mean diastolic bp (mmhg)  mean systolic bp (mmhg)  \
# 0                        73.5                    125.0
# 1                        75.5                    112.0
# 2                        70.5                    116.0
# 3                        92.5                    167.0
# 4                        79.0                    137.0
# ..                        ...                      ...
# 128                      74.5                    128.5
# 129                      84.0                    125.0
# 130                      76.0                    140.5
# 131                      83.5                    122.5
# 132                      92.0                    156.5
#
#      central armellini fat (mm) current gestational age  pregnancies (number)  \
# 0                         28.10                    12,1                   1.0
# 1                         43.10                    11,5                   1.0
# 2                         41.40                    12,6                   1.0
# 3                         39.60                    16,2                   4.0
# 4                         67.80                    11,2                   2.0
# ..                          ...                     ...                   ...
# 128                       13.90                    10,4                   2.0
# 129                       69.05                     7,5                   2.0
# 130                       52.50                    20,0                   2.0
# 131                       31.45                    10,5                   1.0
# 132                       42.50                     8,5                   4.0
#
#      first fasting glucose (mg/dl)  bmi pregestational (kg/m)  \
# 0                              NaN                      33.20
# 1                             76.0                      21.50
# 2                             86.0                      21.41
# 3                              NaN                      55.36
# 4                             86.0                      30.85
# ..                             ...                        ...
# 128                           81.0                      21.22
# 129                          114.0                      36.64
# 130                           88.0                      23.62
# 131                            NaN                      28.76
# 132                            NaN                      44.43
#
#     gestational age at birth  type of delivery  child birth weight (g)  \
# 0                       41,0                 1                    3840
# 1                       39,1                 0                    2810
# 2                       39,5                 0                    2455
# 3                       39,4                 0                    3400
# 4                       40,2                 1                    3930
# ..                       ...               ...                     ...
# 128                     38,3                 0                    3775
# 129                     37,3                 1                    3565
# 130                     40,3                 1                    3260
# 131                     40,6                 1                    3270
# 132                     40,4                 0                    4226
#
#      gestational dm
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 1
# ..              ...
# 128               0
# 129               1
# 130               0
# 131               0
# 132               0
#
# [133 rows x 15 columns]

# %%
def converte_idade_gestacional(texto):
    partes_do_texto = texto.split(',')
    semanas = int(partes_do_texto[0])
    dias = int(partes_do_texto[1])
    return 7*semanas + dias

data['current gestational age'] = data['current gestational age'].apply(converte_idade_gestacional)
data['gestational age at birth'] = data['gestational age at birth'].apply(converte_idade_gestacional)

# %%
data
# Out:
#      number  age (years)  ethnicity  diabetes mellitus  \
# 0         1           20        NaN                  0
# 1         2           28        0.0                  0
# 2         5           21        1.0                  0
# 3         9           25        0.0                  0
# 4        13           33        1.0                  0
# ..      ...          ...        ...                ...
# 128     278           21        0.0                  0
# 129     280           22        0.0                  0
# 130     283           19        1.0                  0
# 131     285           23        1.0                  0
# 132     287           36        0.0                  0
#
#      mean diastolic bp (mmhg)  mean systolic bp (mmhg)  \
# 0                        73.5                    125.0
# 1                        75.5                    112.0
# 2                        70.5                    116.0
# 3                        92.5                    167.0
# 4                        79.0                    137.0
# ..                        ...                      ...
# 128                      74.5                    128.5
# 129                      84.0                    125.0
# 130                      76.0                    140.5
# 131                      83.5                    122.5
# 132                      92.0                    156.5
#
#      central armellini fat (mm)  current gestational age  \
# 0                         28.10                       85
# 1                         43.10                       82
# 2                         41.40                       90
# 3                         39.60                      114
# 4                         67.80                       79
# ..                          ...                      ...
# 128                       13.90                       74
# 129                       69.05                       54
# 130                       52.50                      140
# 131                       31.45                       75
# 132                       42.50                       61
#
#      pregnancies (number)  first fasting glucose (mg/dl)  \
# 0                     1.0                            NaN
# 1                     1.0                           76.0
# 2                     1.0                           86.0
# 3                     4.0                            NaN
# 4                     2.0                           86.0
# ..                    ...                            ...
# 128                   2.0                           81.0
# 129                   2.0                          114.0
# 130                   2.0                           88.0
# 131                   1.0                            NaN
# 132                   4.0                            NaN
#
#      bmi pregestational (kg/m)  gestational age at birth  type of delivery  \
# 0                        33.20                       287                 1
# 1                        21.50                       274                 0
# 2                        21.41                       278                 0
# 3                        55.36                       277                 0
# 4                        30.85                       282                 1
# ..                         ...                       ...               ...
# 128                      21.22                       269                 0
# 129                      36.64                       262                 1
# 130                      23.62                       283                 1
# 131                      28.76                       286                 1
# 132                      44.43                       284                 0
#
#      child birth weight (g)  gestational dm
# 0                      3840               0
# 1                      2810               0
# 2                      2455               0
# 3                      3400               0
# 4                      3930               1
# ..                      ...             ...
# 128                    3775               0
# 129                    3565               1
# 130                    3260               0
# 131                    3270               0
# 132                    4226               0
#
# [133 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   number                         133 non-null    int64
#  1   age (years)                    133 non-null    int64
#  2   ethnicity                      132 non-null    float64
#  3   diabetes mellitus              133 non-null    int64
#  4   mean diastolic bp (mmhg)       133 non-null    float64
#  5   mean systolic bp (mmhg)        133 non-null    float64
#  6   central armellini fat (mm)     133 non-null    float64
#  7   current gestational age        133 non-null    int64
#  8   pregnancies (number)           128 non-null    float64
#  9   first fasting glucose (mg/dl)  103 non-null    float64
#  10  bmi pregestational (kg/m)      132 non-null    float64
#  11  gestational age at birth       133 non-null    int64
#  12  type of delivery               133 non-null    int64
#  13  child birth weight (g)         133 non-null    int64
#  14  gestational dm                 133 non-null    int64
# dtypes: float64(7), int64(8)
# memory usage: 15.7 KB

# %%
data = data.drop(columns=['number', 'diabetes mellitus'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age (years)                    133 non-null    int64
#  1   ethnicity                      132 non-null    float64
#  2   mean diastolic bp (mmhg)       133 non-null    float64
#  3   mean systolic bp (mmhg)        133 non-null    float64
#  4   central armellini fat (mm)     133 non-null    float64
#  5   current gestational age        133 non-null    int64
#  6   pregnancies (number)           128 non-null    float64
#  7   first fasting glucose (mg/dl)  103 non-null    float64
#  8   bmi pregestational (kg/m)      132 non-null    float64
#  9   gestational age at birth       133 non-null    int64
#  10  type of delivery               133 non-null    int64
#  11  child birth weight (g)         133 non-null    int64
#  12  gestational dm                 133 non-null    int64
# dtypes: float64(7), int64(6)
# memory usage: 13.6 KB

# %%
data = data.dropna(axis=0)

# %%
data
# Out:
#      age (years)  ethnicity  mean diastolic bp (mmhg)  \
# 1             28        0.0                      75.5
# 2             21        1.0                      70.5
# 4             33        1.0                      79.0
# 5             18        0.0                      67.5
# 7             20        1.0                      74.5
# ..           ...        ...                       ...
# 125           17        1.0                      76.5
# 127           21        0.0                      63.5
# 128           21        0.0                      74.5
# 129           22        0.0                      84.0
# 130           19        1.0                      76.0
#
#      mean systolic bp (mmhg)  central armellini fat (mm)  \
# 1                      112.0                       43.10
# 2                      116.0                       41.40
# 4                      137.0                       67.80
# 5                      111.5                       26.80
# 7                      114.0                       20.60
# ..                       ...                         ...
# 125                    126.0                       38.60
# 127                    111.5                       72.30
# 128                    128.5                       13.90
# 129                    125.0                       69.05
# 130                    140.5                       52.50
#
#      current gestational age  pregnancies (number)  \
# 1                         82                   1.0
# 2                         90                   1.0
# 4                         79                   2.0
# 5                         89                   1.0
# 7                        105                   1.0
# ..                       ...                   ...
# 125                      122                   1.0
# 127                      140                   1.0
# 128                       74                   2.0
# 129                       54                   2.0
# 130                      140                   2.0
#
#      first fasting glucose (mg/dl)  bmi pregestational (kg/m)  \
# 1                             76.0                      21.50
# 2                             86.0                      21.41
# 4                             86.0                      30.85
# 5                             80.3                      22.60
# 7                             74.0                      19.66
# ..                             ...                        ...
# 125                           78.0                      26.22
# 127                           86.0                      31.22
# 128                           81.0                      21.22
# 129                          114.0                      36.64
# 130                           88.0                      23.62
#
#      gestational age at birth  type of delivery  child birth weight (g)  \
# 1                         274                 0                    2810
# 2                         278                 0                    2455
# 4                         282                 1                    3930
# 5                         287                 0                    2730
# 7                         280                 0                    3610
# ..                        ...               ...                     ...
# 125                       287                 0                    3765
# 127                       276                 0                    3155
# 128                       269                 0                    3775
# 129                       262                 1                    3565
# 130                       283                 1                    3260
#
#      gestational dm
# 1                 0
# 2                 0
# 4                 1
# 5                 0
# 7                 0
# ..              ...
# 125               0
# 127               0
# 128               0
# 129               1
# 130               0
#
# [101 rows x 13 columns]
